# %% [markdown]
# Linklist
# 1) big (o notes) -> file:///Users/ojoshi/Downloads/LL+vs+Lists+-Big+O.pdf

# %% [markdown]
# How to create a linklist in python

# %%
head = {
    "value": 11,
    "next": {
        "value": 12,
        "next": {
            "value": 67,
            "next": None,
        },
    },
}
print(head["next"]["next"]["value"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import linkedlist as my_linked_list
#       3 head = {"value": 11,"next":{"value":12, "next":{"value":67, "next":None}}}
#       4 print(my_linked_list.head.next.next.value)
#
# ModuleNotFoundError: No module named 'linkedlist'
