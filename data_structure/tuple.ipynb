# %%
## creating a tuple
tuple =()
print (type(tuple))
# Out:
# <class 'tuple'>

# %%
## adding a element

tuple = (1,"hello world",3.14,True)
print (tuple)
# Out:
# (1, 'hello world', 3.14, True)

# %%
## accessing the tuple
print (tuple[1])
print (tuple[2])
# Out:
# hello world
# 3.14

# %%
## Immutable nature of tuple
## you can not change the element once you assign it 

tuple = (1,2,3,4,5,6,7)
print(tuple)

print(tuple[1])
# Out:
# (1, 2, 3, 4, 5, 6, 7)
# 2

# %%
tuple[1]="omkar"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tuple[1]="omkar"
#
# TypeError: 'tuple' object does not support item assignment

# %%
## packing and upacking tuple
packed_tuple = 1,"hello",3.14
print(packed_tuple)
# Out:
# (1, 'hello', 3.14)
